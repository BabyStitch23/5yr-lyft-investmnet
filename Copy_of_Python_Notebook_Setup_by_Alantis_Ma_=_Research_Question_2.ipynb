# %% [markdown]
# <a href="https://colab.research.google.com/github/BabyStitch23/5yr-lyft-investmnet/blob/main/Copy_of_Python_Notebook_Setup_by_Alantis_Ma_%3D_Research_Question_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # 2 : **Is there an association between the amount of fast foods eaten and time spent on the internet, in the past week?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# **Codebook 1: Internet_Hours_Week**

# %% [markdown]
# ![Screenshot_4.png](data:image/png;base64,...)

# %%
#Manage data for variable 1

df['Internet_Hours_Week'] = df['H4DA22']

df['Internet_Hours_Week']= pd.to_numeric(df['Internet_Hours_Week'],errors= 'coerce')
df['Internet_Hours_Week']= df['Internet_Hours_Week'].loc[df['Internet_Hours_Week'] < 996]
df['Internet_Hours_Week']= df['Internet_Hours_Week'].loc[df['Internet_Hours_Week'] != ' ']

# %%
#Frequency Table

df['Internet_Hours_Week'].describe()
# Out:
# count    4936.000000
# mean        5.994935
# std         9.368910
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max       105.000000
# Name: Internet_Hours_Week, dtype: float64

# %%
#Boxplot

sns.boxplot(x = 'Internet_Hours_Week', data =df, color ='green')
# Out:
# <Axes: xlabel='Internet_Hours_Week'>

# %%
#Histogram

sns.histplot(x= 'Internet_Hours_Week', data = df, stat='percent', bins=14, kde=True)
# Out:
# <Axes: xlabel='Internet_Hours_Week', ylabel='Percent'>

# %% [markdown]
# **Codebook 2: Fast_foods_Week**

# %% [markdown]
# ![Screenshot_5.png](data:image/png;base64,...)

# %%
#Manage data for variable 2

df['Fast_Foods_Week'] = df['H4GH8']

df['Fast_Foods_Week']= pd.to_numeric(df['Fast_Foods_Week'],errors= 'coerce')
df['Fast_Foods_Week']= df['Fast_Foods_Week'].loc[df['Fast_Foods_Week'] < 996]
df['Fast_Foods_Week']= df['Fast_Foods_Week'].loc[df['Fast_Foods_Week'] != ' ']

# %%
#Frequency Table

df['Fast_Foods_Week'].describe()
# Out:
# count    5079.000000
# mean        2.376058
# std         3.433947
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        99.000000
# Name: Fast_Foods_Week, dtype: float64

# %%
#Boxplot

sns.boxplot(x = 'Fast_Foods_Week', data =df, color ='purple')
# Out:
# <Axes: xlabel='Fast_Foods_Week'>

# %%
#Histogram

sns.histplot(x= 'Fast_Foods_Week', data = df, stat='percent', bins=14, kde=True)
# Out:
# <Axes: xlabel='Fast_Foods_Week', ylabel='Percent'>
